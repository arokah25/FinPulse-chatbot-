# %%
import sys
from pathlib import Path
from dotenv import load_dotenv

#point python to src / package
sys.path.insert(0, str(Path().cwd().parents[1]))


load_dotenv()

from finpulse.report.generator import ReportGenerator

# %%
#TEST: test ReportGenerator
test_apple_gen = ReportGenerator()

result_apple = test_apple_gen.generate_report(ticker="AAPL", form_type="10-Q", query="latest quarterly performance")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760988146.507190 2202662 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
print(result_apple)
# Out:
# {'ticker': 'AAPL', 'cik': '0000320193', 'form_type': '10-Q', 'kpis': {'NetIncomeLoss': {'value': 23434000000, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'EarningsPerShareDiluted': {'value': 1.57, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'CashAndCashEquivalentsAtCarryingValue': {'value': 36269000000, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'LongTermDebtNoncurrent': {'value': 82430000000, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}}, 'kpi_table': '| Metric | Value | Period | Filing |\n|--------|-------|--------|--------|\n| NetIncomeLoss | $23.43B | 2025-06-28 | 10-Q |\n| EarningsPerShareDiluted | $1.57 | 2025-06-28 | 10-Q |\n| CashAndCashEquivalentsAtCarryingValue | $36.27B | 2025-06-28 | 10-Q |\n| LongTermDebtNoncurrent | $82.43B | 2025-06-28 | 10-Q |\n', 'narrative': "For the latest quarterly performance, specifically as of June 28, 2025 [S1], the company reported a net income of $23.434 billion [
# ...
