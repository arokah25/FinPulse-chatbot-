# %%
import sys
from pathlib import Path
from dotenv import load_dotenv

#point python to src / package
sys.path.insert(0, str(Path().cwd().parents[1]))


load_dotenv()

from finpulse.report.generator import ReportGenerator

# %%
test_apple_gen = ReportGenerator()

result_apple = test_apple_gen.generate_report(ticker="AAPL", form_type="10-Q", query="latest quarterly performance")
# Out:
# E0000 00:00:1760963990.686632 1770533 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
print(result_apple)
# Out:
# {'ticker': 'AAPL', 'cik': '0000320193', 'form_type': '10-Q', 'kpis': {'NetIncomeLoss': {'value': 23434000000, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'EarningsPerShareDiluted': {'value': 1.57, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'CashAndCashEquivalentsAtCarryingValue': {'value': 36269000000, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'LongTermDebtNoncurrent': {'value': 82430000000, 'period': '2025-06-28', 'form': '10-Q', 'filed': '2025-08-01'}, 'Revenue_9_Months': {'value': 313695000000.0, 'period': 'Last 3 quarters (2024-12-28, 2025-03-29, 2025-06-28)', 'form': '10-Q', 'filed': 'From SEC XBRL data and filing text'}}, 'kpi_table': '| Metric | Value | Period | Filing |\n|--------|-------|--------|--------|\n| NetIncomeLoss | $23.43B | 2025-06-28 | 10-Q |\n| EarningsPerShareDiluted | $1.57 | 2025-06-28 | 10-Q |\n| CashAndCashEquivalentsAtCarryingValue | $36.27B | 2025-06-28 | 10-Q |\n| LongTermDebtNoncurrent | $82.43B | 2025-06-28 | 10-Q |\n| Revenue_9_Months | $313.69B | Last 3 quarters (2024-12-28, 2025-03-29, 2025-06-28) | 10-Q |\n', 'narrative': "Based on the latest 10-Q filing for the quarter ending June 28, 2025, the company reported a net income of $23.434 billion [NetIncomeLoss, as of 2025-06-28, 10-Q]. This translates to diluted earnings per share of $1.57 [EarningsPerShareDiluted, as of 2025-06-28, 10-Q]. The company's cash and cash equivalents stand at $36.269 billion [CashAndCashEquivalentsAtCarryingValue, as of 2025-06-28, 10-Q], while long-term debt is reported as $82.430 billion [LongTermDebtNoncurrent, as of 2025-06-28, 10-Q]. Revenue for the past three quarters (including the latest) totaled $313.695 billion [Revenue_9_Months, as of Last 3 quarters (2024-12-28, 2025-03-29, 2025-06-28), 10-Q]. It is important to note that the company will be adopting ASU 2023-07 in the fourth quarter of 2025, which will require additional disclosures related to segment performance assessment [S1, S2, S3, S4, S5]. This change will provide more transparency on how the company's Chief Operating Decision Maker (CODM) uses segment profit or loss information.\n\n**Sources:**\n- [S1]: https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000057/aapl-20250329.htm\n- [S2]: https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000057/aapl-20250329.htm\n- [S3]: https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000057/aapl-20250329.htm\n- [S4]: https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000057/aapl-20250329.htm\n- [S5]: https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000057/aapl-20250329.htm\n", 'sources': [('10-Q filed 2025-08-01', 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000073/aapl-20250628.htm', 1.0), ('10-Q filed 2025-05-02', 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000057/aapl-20250329.htm', 1.0), ('10-Q filed 2025-01-31', 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019325000008/aapl-20241228.htm', 1.0)], 'filings_analyzed': 3, 'query': 'latest quarterly performance', 'entityName': 'Apple Inc.'}
